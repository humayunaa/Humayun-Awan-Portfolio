# %% [markdown]
# # Data Information
# - This notebook trains a k-nearest neighbour model which contains movie reviews with a positive or negative label

# %% [markdown]
# ### Install sklearn: python library for machine learning

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\humay\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\humay\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\humay\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\humay\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\humay\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Install datasets: access IMDB dataset

# %%
pip install datasets
# Out:
# Requirement already satisfied: datasets in c:\users\humay\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: filelock in c:\users\humay\anaconda3\lib\site-packages (from datasets) (3.9.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\humay\anaconda3\lib\site-packages (from datasets) (1.24.3)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\humay\anaconda3\lib\site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\humay\anaconda3\lib\site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in c:\users\humay\anaconda3\lib\site-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\humay\anaconda3\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\humay\anaconda3\lib\site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in c:\users\humay\anaconda3\lib\site-packages (from datasets) (2.0.2)
# Requirement already satisfied: multiprocess in c:\users\humay\anaconda3\lib\site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]<=2024.6.1,>=2023.1.0 in c:\users\humay\anaconda3\lib\site-packages (from datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in c:\users\humay\anaconda3\lib\site-packages (from datasets) (3.8.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in c:\users\humay\anaconda3\lib\site-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in c:\users\humay\anaconda3\lib\site-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\humay\anaconda3\lib\site-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\humay\anaconda3\lib\site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\humay\anaconda3\lib\site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\humay\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\humay\anaconda3\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\humay\anaconda3\lib\site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\humay\anaconda3\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\humay\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\humay\anaconda3\lib\site-packages (from huggingface-hub>=0.22.0->datasets) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\humay\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\humay\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\humay\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\humay\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\humay\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\humay\anaconda3\lib\site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\humay\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\humay\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import load_dataset

imdb_dataset = load_dataset("imdb")["train"]
print(imdb_dataset[-1])
# Out:
# {'text': 'The story centers around Barry McKenzie who must go to England if he wishes to claim his inheritance. Being about the grossest Aussie shearer ever to set foot outside this great Nation of ours there is something of a culture clash and much fun and games ensue. The songs of Barry McKenzie(Barry Crocker) are highlights.', 'label': 1}

# %% [markdown]
# ### Look at IMDB reviews in DataFrame

# %%
import pandas as pd
df = pd.DataFrame(imdb_dataset)

print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
df.head()
# Out:
# Number of rows: 25000
# Number of columns: 2
#                                                 text  label
# 0  I rented I AM CURIOUS-YELLOW from my video sto...      0
# 1  "I Am Curious: Yellow" is a risible and preten...      0
# 2  If only to avoid making this type of film in t...      0
# 3  This film was probably inspired by Godard's Ma...      0
# 4  Oh, brother...after hearing about this ridicul...      0

# %% [markdown]
# ### Convert training data into format scikit-learn expects
# - Input vectors (documents) and a list of associated output labels

# %%
train_data = []
train_data_labels = []
for item in imdb_dataset:
    train_data.append(item["text"])
    train_data_labels.append(item["label"])

print(train_data[5])
print(train_data_labels[5])
# Out:
# I would put this at the top of my list of films in the category of unwatchable trash! There are films that are bad, but the worst kind are the ones that are unwatchable but you are suppose to like them because they are supposed to be good for you! The sex sequences, so shocking in its day, couldn't even arouse a rabbit. The so called controversial politics is strictly high school sophomore amateur night Marxism. The film is self-consciously arty in the worst sense of the term. The photography is in a harsh grainy black and white. Some scenes are out of focus or taken from the wrong angle. Even the sound is bad! And some people call this art?<br /><br />
# 0

# %% [markdown]
# This is a film review and its label. We can clearly see that this is a negative film review. We see this with key phrases such as "unwatchable trash", "Even the sound is bad!" and a sarcastic remark at the end, "And some people call this art?"
#
# The label for this review is 0. We can assume: 1 = positive review | 0 = negative review

# %% [markdown]
# ### Import CountVectorizer
# - Use the CountVectorizer class to extract the words in each review as the features the algorithm will learn from.
# - Each document is represented as a 500 dimension vector of word counts. Only the 500 most frequent words are used in this version.

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(analyzer="word", max_features=500, lowercase=True)
features = vectorizer.fit_transform(train_data).toarray()

# %% [markdown]
# Check we have a 2-D array where each row is one of 25,000 instances. Each column is one of 200 words. Print out words that will be used classification

# %%
print(features.shape)
print(vectorizer.get_feature_names_out())
# Out:
# (25000, 500)
# ['10' 'able' 'about' 'absolutely' 'act' 'acting' 'action' 'actor' 'actors'
#  'actress' 'actually' 'after' 'again' 'against' 'all' 'almost' 'along'
#  'already' 'also' 'although' 'always' 'am' 'amazing' 'american' 'an' 'and'
#  'another' 'any' 'anyone' 'anything' 'are' 'around' 'art' 'as' 'at'
#  'audience' 'away' 'awful' 'back' 'bad' 'based' 'be' 'beautiful' 'because'
#  'become' 'becomes' 'been' 'before' 'beginning' 'behind' 'being' 'believe'
#  'best' 'better' 'between' 'big' 'bit' 'black' 'book' 'boring' 'both'
#  'boy' 'br' 'budget' 'but' 'by' 'called' 'came' 'camera' 'can' 'car'
#  'care' 'case' 'cast' 'certainly' 'character' 'characters' 'child'
#  'children' 'cinema' 'classic' 'close' 'come' 'comedy' 'comes'
#  'completely' 'could' 'couldn' 'couple' 'course' 'dark' 'day' 'days'
#  'dead' 'death' 'definitely' 'despite' 'dialogue' 'did' 'didn' 'different'
#  'direction' 'director' 'do' 'does' 'doesn' 'doing' 'don' 'done' 'down'
#  'drama' 'during' 'dvd' 'each' 'early' 'effects' 'either' 'else' 'end'
#  'ending' 'enjoy' 'enjoyed' 'enough' 'entertaining' 'entire' 'episode'
#  'especially' 'even' 'ever' 'every' 'everyone' 'everything' 'evil'
#  'example' 'excellent' 'face' 'fact' 'family' 'fan' 'fans' 'far' 'father'
#  'favorite' 'feel' 'felt' 'few' 'film' 'films' 'final' 'finally' 'find'
#  'fine' 'first' 'flick' 'for' 'found' 'friend' 'friends' 'from' 'full'
#  'fun' 'funny' 'game' 'genre' 'get' 'gets' 'getting' 'girl' 'give' 'given'
#  'gives' 'go' 'goes' 'going' 'good' 'got' 'great' 'guess' 'guy' 'guys'
#  'had' 'half' 'hand' 'hard' 'has' 'have' 'having' 'he' 'head' 'heart'
#  'help' 'her' 'here' 'high' 'him' 'himself' 'his' 'history' 'hollywood'
#  'home' 'hope' 'horror' 'house' 'how' 'however' 'human' 'humor' 'idea'
#  'if' 'in' 'instead' 'interesting' 'into' 'is' 'isn' 'it' 'its' 'itself'
#  'job' 'john' 'just' 'keep' 'kids' 'kill' 'killer' 'kind' 'know' 'last'
#  'later' 'laugh' 'lead' 'least' 'left' 'less' 'let' 'life' 'like' 'liked'
#  'line' 'lines' 'little' 'live' 'lives' 'll' 'long' 'look' 'looking'
#  'looks' 'lost' 'lot' 'love' 'loved' 'low' 'made' 'main' 'make' 'makes'
#  'making' 'man' 'many' 'may' 'maybe' 'me' 'mean' 'men' 'michael' 'might'
#  'mind' 'minutes' 'moments' 'money' 'more' 'most' 'mother' 'movie'
#  'movies' 'mr' 'much' 'music' 'must' 'my' 'name' 'need' 'never' 'new'
#  'next' 'nice' 'night' 'no' 'not' 'nothing' 'now' 'of' 'off' 'often' 'oh'
#  'old' 'on' 'once' 'one' 'only' 'or' 'original' 'other' 'others' 'our'
#  'out' 'over' 'overall' 'own' 'part' 'past' 'people' 'perfect'
#  'performance' 'performances' 'perhaps' 'person' 'picture' 'piece' 'place'
#  'play' 'played' 'playing' 'plays' 'plot' 'point' 'poor' 'pretty'
#  'probably' 'problem' 'production' 'put' 'quality' 'quite' 'rather' 're'
#  'read' 'real' 'really' 'reason' 'recommend' 'remember' 'rest' 'right'
#  'role' 'said' 'same' 'saw' 'say' 'scene' 'scenes' 'school' 'screen'
#  'script' 'second' 'see' 'seeing' 'seem' 'seemed' 'seems' 'seen' 'sense'
#  'series' 'set' 'several' 'sex' 'she' 'short' 'shot' 'should' 'show'
#  'shows' 'side' 'simply' 'since' 'small' 'so' 'some' 'someone' 'something'
#  'son' 'soon' 'sort' 'sound' 'special' 'star' 'stars' 'start' 'still'
#  'story' 'stupid' 'style' 'such' 'supposed' 'sure' 'take' 'takes' 'tell'
#  'terrible' 'than' 'that' 'the' 'their' 'them' 'then' 'there' 'these'
#  'they' 'thing' 'things' 'think' 'this' 'those' 'though' 'thought' 'three'
#  'through' 'throughout' 'time' 'times' 'title' 'to' 'today' 'together'
#  'too' 'top' 'totally' 'town' 'tries' 'true' 'truly' 'try' 'trying' 'turn'
#  'turns' 'tv' 'two' 'under' 'understand' 'unfortunately' 'until' 'up' 'us'
#  'use' 'used' 've' 'version' 'very' 'video' 'viewer' 'want' 'wanted'
#  'wants' 'war' 'was' 'wasn' 'waste' 'watch' 'watched' 'watching' 'way'
#  'we' 'well' 'went' 'were' 'what' 'when' 'where' 'which' 'while' 'white'
#  'who' 'whole' 'why' 'wife' 'will' 'with' 'without' 'woman' 'women' 'won'
#  'wonderful' 'work' 'works' 'world' 'worse' 'worst' 'worth' 'would'
#  'writing' 'written' 'wrong' 'year' 'years' 'yes' 'yet' 'you' 'young'
#  'your']

# %% [markdown]
# Split the data into a training and validation (dev) set. We'll use the validation set to test our model. 90% data for training | 10% data for testing

# %% [markdown]
# ## Make Predictions: K-Nearest Nighbour

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

x_train, x_val, y_train, y_val = train_test_split(features, train_data_labels, train_size=0.9, random_state=123)

model = KNeighborsClassifier(n_neighbors=5)
model = model.fit(X=x_train, y=y_train)

y_pred = model.predict(X=x_val)

# Test accuracy of model
print(f"Accuracy of Model: {accuracy_score(y_val, y_pred)*100}%")
# Out:
# Accuracy of Model: 63.4%

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

labels = [1, 0]

cm = confusion_matrix(y_val, y_pred, labels=labels)
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
cm_percent = cmn * 100

# Create % signs on confusion matrix
annotations = np.asarray([['{:.1f}%'.format(value) for value in row] for row in cm_percent])

# Plot conusion matrix: with %
fig, ax = plt.subplots(figsize=(6, 4))
sns.heatmap(cm_percent, annot=annotations, fmt='', cbar=False, cmap='Reds',
            xticklabels=labels, yticklabels=labels)

print(cm)
# Out:
# [[914 345]
#  [570 671]]

# %% [markdown]
# - True Positive: Almost 73% of positive reviews were correctly predicted as positive = 914
# - False Positive: Just over 27% of positive review were incorrectly predicted as negative = 345
# - True Negative: Just over 54% of negative reviews were correctly predicted as negative = 671
# - False Negative: Almost 46% of negative review were incorrectly predicted as positive = 570

# %% [markdown]
# ## Attempt to Increase Accuracy: K-Nearest Neighbour

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize the TfidfVectorizer with similar parameters
vectorizer_new = TfidfVectorizer(analyzer="word", max_features=5000, lowercase=True)

# Fit and transform the training data
features_new = vectorizer_new.fit_transform(train_data).toarray()

x_train_new, x_val_new, y_train_new, y_val_new = train_test_split(features_new, train_data_labels,
                                                                  train_size=0.9, random_state=123)

model_new = KNeighborsClassifier(n_neighbors=5)
model_new = model_new.fit(X=x_train_new, y=y_train_new)

y_pred_new = model_new.predict(X=x_val_new)

# Compare accuracy of new model
print(f"Accuracy of Old Model: {accuracy_score(y_val, y_pred)*100}%")
print(f"Accuracy of New Model: {accuracy_score(y_val_new, y_pred_new)*100}%")
# Out:
# Accuracy of Old Model: 63.4%
# Accuracy of New Model: 74.68%
